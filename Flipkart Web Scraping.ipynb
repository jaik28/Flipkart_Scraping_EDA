# %% [markdown]
# # Web Scraping
# Data scraping is one of the most used ways to collect data. In simple terms it means, to get HTML code for a webpage and scan it for data.
#
# ### Beautiful Soup is the most used package for scanning/scraping data.
#
# In this notebook we'll see how to use Beautiful Soup and get a set of reviews and its associated metadata posted by the customers on its website for 2 of the headphones and create a dataset out of it.
#
#
# ## Let's Get started:
#
# ### Importing modules
# Request Module is used to get the HTML code for the URL given.

# %%
# libraries for Web Scrapping
import requests
from bs4 import BeautifulSoup

# library for advance string manipulation
import string

# library for data manipulation
import pandas as pd

# library for advance mathematical operations
import numpy as np

# importing os module 
import os 

# libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Extract the html data from the webpage

# %%
# extract the data fro page number 1 only
page_number = 8

# extract the page as a whole
page = requests.get("https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=popularity".format(page_number))

# parse the whole page using a html parser
soup = BeautifulSoup(page.content, 'html.parser')
# soup

# %% [markdown]
# # Find the main class that contains the group items

# %%
# find_all() searches for the all the tags where the class is found and 
# returns a list of all the occurences 
all_laps = soup.findAll('a', href=True, attrs={'class':"_1fQZEK"})

# find the length of the elements extracted
len(all_laps)
# Out:
# 24

# %%
for a in all_laps:
    name = all_laps[7].find('ul', attrs={'class':'_1xgFaf'})
    sp = name.findAll(class_="rgWa7D")
    for i in range(len(sp)):
        if('Processor' in sp[i].text  and 'Processor:' not in sp[i].text):
            processor = sp[i].text
            #print(processor)

        elif('RAM' in sp[i].text and 'RAM &' not in sp[i].text):
            ram = sp[i].text
            #print(ram)

        elif('Operating' in sp[i].text):
            os = sp[i].text
            #print(os)

        elif('SSD' in sp[i].text or 'HDD' in sp[i].text):
            storage = sp[i].text
            #print(storage)

# %%
data = []

for a in all_laps:
    
    processor = None
    ram = None
    os = None
    storage = None
    
    name = a.find('div', attrs={'class':'_4rR01T'})
    ratings = a.find('div', attrs={'class':'_3LWZlK'})
    num_ratings = a.find('span', attrs={'class':'_2_R_DZ'})
    print(name.text)
    price = a.find(class_='_30jeq3 _1_WHN1')
    org_price = a.find(class_='_3I9_wc _27UcVY')
    print(price.text)
    
    allspecs = a.find('ul', attrs={'class':'_1xgFaf'})
    sp = allspecs.findAll(class_="rgWa7D")

    for i in range(len(sp)):
        if('Processor' in sp[i].text  and 'Processor:' not in sp[i].text):
            processor = sp[i]
           
        elif('RAM' in sp[i].text and 'RAM &' not in sp[i].text):
            ram = sp[i]
            
        elif('Operating' in sp[i].text):
            os = sp[i]
            
        elif('SSD' in sp[i].text or 'HDD' in sp[i].text):
            storage = sp[i].text
            print(storage)
            
    data.append({'name': name.text,
                 'ratings': ratings.text if ratings is not None else '',
                 'num_ratings': num_ratings.text if num_ratings is not None else '',
                'processor': processor.text,
                'ram': ram.text,
                'os': os.text,
                'storage': storage if storage is not None else '',
                'price': price.text,
                'org_price': org_price.text if org_price is not None else ''})
    print('_______________')
# Out:
# ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS | X515JA-E...
# ₹32,990
# 512 GB SSD
# _______________
# HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 10/4 GB Graphics/NVIDIA GeForce ...
# ₹49,990
# 512 GB SSD
# _______________
# Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop
# ₹28,490
# 256 GB SSD
# _______________
# HP 14s Intel Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14s - dy2507TU Thin and Light Laptop
# ₹35,990
# 256 GB SSD
# _______________
# acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/Windows 11 Home) A315-23 Laptop
# ₹26,990
# 256 GB SSD
# _______________
# Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) V15 ITL G2 Laptop
# ₹33,599
# 512 GB SSD
# _______________
# Lenovo V15 G2 Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) V15 ITL G2 Laptop
# ₹35,499
# 1 TB HDD|256 GB SSD
# _______________
# DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) Vostro 3510 Thin and Light L...
# ₹39,990
# RAM & Storage: 8GB DDR4 & 1TB HDD + 256GB SSD
# 1 TB HDD|256 GB SSD
# _______________
# ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5 Hexa Core AMD R5-4600H - (8 GB/512 GB SSD/Windows 11 Ho...
# ₹52,990
# 512 GB SSD
# _______________
# ASUS ROG Strix G15 (2021) Ryzen 7 Octa Core AMD R7-4800H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graph...
# ₹75,490
# 512 GB SSD
# _______________
# RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop
# ₹39,990
# 512 GB SSD
# _______________
# ASUS Vivobook Ultra 14 (2022) Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) K413EA-EB522WS Thi...
# ₹53,990
# 512 GB SSD
# _______________
# ASUS VivoBook 14 (2021) Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) X415MA-BV011W Thin and L...
# ₹23,990
# 256 GB SSD
# _______________
# HP Intel Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s- fr4000TU Thin and Light Laptop
# ₹52,990
# 512 GB SSD
# _______________
# Lenovo Celeron Dual Core - (4 GB/256 GB HDD/256 GB SSD/DOS) 82C3A00DIH Laptop
# ₹19,990
# 256 GB HDD|256 GB SSD
# _______________
# HP 14s Intel Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14s - dy5005TU Thin and Light Lapto...
# ₹58,899
# 512 GB SSD
# _______________
# ASUS Core i7 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) X515EA-EJ701WS Thin and Light Laptop
# ₹56,990
# 512 GB SSD
# _______________
# Lenovo Athlon Dual Core 3150U - (4 GB/1 TB HDD/DOS) E41-55 Thin and Light Laptop
# ₹18,990
# 1 TB HDD
# _______________
# ASUS Vivobook 15 Touch Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EZ311WS Thin and Li...
# ₹41,990
# 512 GB SSD
# _______________
# HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/Windows 11 Home) 15s-ey1508AU Thin and Light Laptop
# ₹29,990
# 256 GB SSD
# _______________
# HP 15s Intel Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq5111TU Thin and Light Laptop
# ₹56,899
# 512 GB SSD
# _______________
# ASUS Vivobook 15 Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ382WS X515JA Laptop
# ₹33,990
# 512 GB SSD
# _______________
# DELL Ryzen 3 Quad Core 5425U - (8 GB/256 GB SSD/Windows 11 Home) Vostro 3425 Thin and Light Laptop
# ₹35,990
# RAM & Storage: 8GB DDR4 & 256GB SSD
# 256 GB SSD
# _______________
# ASUS ROG Strix G15 Ryzen 7 Octa Core AMD R7-4800H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVI...
# ₹76,990
# 512 GB SSD
# _______________

# %%
data
# Out:
# [{'name': 'ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS | X515JA-E...',
#   'ratings': '4.3',
#   'num_ratings': '9,965 Ratings\xa0&\xa01,000 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹32,990',
#   'org_price': '₹45,990'},
#  {'name': 'HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 10/4 GB Graphics/NVIDIA GeForce ...',
#   'ratings': '4.4',
#   'num_ratings': '11,810 Ratings\xa0&\xa01,198 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹49,990',
#   'org_price': '₹63,539'},
#  {'name': 'Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop',
#   'ratings': '4.1',
#   'num_ratings': '366 Ratings\xa0&\xa035 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹28,490',
#   'org_price': '₹40,490'},
#  {'name': 'HP 14s Intel Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14s - dy2507TU Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '1,539 Ratings\xa0&\xa0136 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹35,990',
#   'org_price': '₹47,206'},
#  {'name': 'acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/Windows 11 Home) A315-23 Laptop',
#   'ratings': '4.2',
#   'num_ratings': '247 Ratings\xa0&\xa053 Reviews',
#   'processor': 'AMD Ryzen 3 Dual Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹26,990',
#   'org_price': '₹42,999'},
#  {'name': 'Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) V15 ITL G2 Laptop',
#   'ratings': '4.1',
#   'num_ratings': '14 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹33,599',
#   'org_price': '₹59,760'},
#  {'name': 'Lenovo V15 G2 Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) V15 ITL G2 Laptop',
#   'ratings': '3.9',
#   'num_ratings': '10 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹35,499',
#   'org_price': '₹60,120'},
#  {'name': 'DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) Vostro 3510 Thin and Light L...',
#   'ratings': '4.1',
#   'num_ratings': '32 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹39,990',
#   'org_price': '₹58,489'},
#  {'name': 'ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5 Hexa Core AMD R5-4600H - (8 GB/512 GB SSD/Windows 11 Ho...',
#   'ratings': '4.4',
#   'num_ratings': '1,340 Ratings\xa0&\xa0166 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹52,990',
#   'org_price': '₹71,990'},
#  {'name': 'ASUS ROG Strix G15 (2021) Ryzen 7 Octa Core AMD R7-4800H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graph...',
#   'ratings': '4.5',
#   'num_ratings': '2,015 Ratings\xa0&\xa0256 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹75,490',
#   'org_price': '₹90,990'},
#  {'name': 'RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop',
#   'ratings': '4.1',
#   'num_ratings': '3,620 Ratings\xa0&\xa0429 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹39,990',
#   'org_price': '₹59,999'},
#  {'name': 'ASUS Vivobook Ultra 14 (2022) Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) K413EA-EB522WS Thi...',
#   'ratings': '4.4',
#   'num_ratings': '153 Ratings\xa0&\xa017 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹53,990',
#   'org_price': '₹81,990'},
#  {'name': 'ASUS VivoBook 14 (2021) Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) X415MA-BV011W Thin and L...',
#   'ratings': '4.1',
#   'num_ratings': '698 Ratings\xa0&\xa086 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '4 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹23,990',
#   'org_price': '₹33,990'},
#  {'name': 'HP Intel Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s- fr4000TU Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '25 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹52,990',
#   'org_price': '₹56,903'},
#  {'name': 'Lenovo Celeron Dual Core - (4 GB/256 GB HDD/256 GB SSD/DOS) 82C3A00DIH Laptop',
#   'ratings': '3.8',
#   'num_ratings': '204 Ratings\xa0&\xa017 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '4 GB LPDDR4 RAM',
#   'os': 'DOS Operating System',
#   'storage': '256 GB HDD|256 GB SSD',
#   'price': '₹19,990',
#   'org_price': '₹36,000'},
#  {'name': 'HP 14s Intel Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14s - dy5005TU Thin and Light Lapto...',
#   'ratings': '4.2',
#   'num_ratings': '1,278 Ratings\xa0&\xa0117 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹58,899',
#   'org_price': '₹75,191'},
#  {'name': 'ASUS Core i7 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) X515EA-EJ701WS Thin and Light Laptop',
#   'ratings': '4',
#   'num_ratings': '83 Ratings\xa0&\xa011 Reviews',
#   'processor': 'Intel Core i7 Processor (11th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹56,990',
#   'org_price': '₹80,990'},
#  {'name': 'Lenovo Athlon Dual Core 3150U - (4 GB/1 TB HDD/DOS) E41-55 Thin and Light Laptop',
#   'ratings': '3.8',
#   'num_ratings': '13 Ratings\xa0&\xa02 Reviews',
#   'processor': 'AMD Athlon Dual Core Processor',
#   'ram': '4 GB DDR4 RAM',
#   'os': 'DOS Operating System',
#   'storage': '1 TB HDD',
#   'price': '₹18,990',
#   'org_price': '₹29,999'},
#  {'name': 'ASUS Vivobook 15 Touch Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EZ311WS Thin and Li...',
#   'ratings': '4.3',
#   'num_ratings': '314 Ratings\xa0&\xa042 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹41,990',
#   'org_price': '₹60,990'},
#  {'name': 'HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/Windows 11 Home) 15s-ey1508AU Thin and Light Laptop',
#   'ratings': '4.1',
#   'num_ratings': '1,060 Ratings\xa0&\xa0106 Reviews',
#   'processor': 'AMD Ryzen 3 Dual Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹29,990',
#   'org_price': '₹43,631'},
#  {'name': 'HP 15s Intel Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq5111TU Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '1,906 Ratings\xa0&\xa0160 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹56,899',
#   'org_price': '₹70,235'},
#  {'name': 'ASUS Vivobook 15 Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ382WS X515JA Laptop',
#   'ratings': '4.1',
#   'num_ratings': '168 Ratings\xa0&\xa014 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹33,990',
#   'org_price': '₹50,990'},
#  {'name': 'DELL Ryzen 3 Quad Core 5425U - (8 GB/256 GB SSD/Windows 11 Home) Vostro 3425 Thin and Light Laptop',
#   'ratings': '4.4',
#   'num_ratings': '87 Ratings\xa0&\xa015 Reviews',
#   'processor': 'AMD Ryzen 3 Quad Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹35,990',
#   'org_price': '₹50,837'},
#  {'name': 'ASUS ROG Strix G15 Ryzen 7 Octa Core AMD R7-4800H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVI...',
#   'ratings': '4.5',
#   'num_ratings': '193 Ratings\xa0&\xa018 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹76,990',
#   'org_price': '₹90,990'}]

# %%
df = pd.DataFrame.from_dict(data) 
df
# Out:
#                                                  name ratings  \
# 0   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...     4.3
# 1   HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (...     4.4
# 2   Lenovo Intel Celeron Dual Core - (8 GB/256 GB ...     4.1
# 3   HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...     4.2
# 4   acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...     4.2
# 5   Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB ...     4.1
# 6   Lenovo V15 G2 Core i3 11th Gen - (8 GB/1 TB HD...     3.9
# 7   DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...     4.1
# 8   ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5...     4.4
# 9   ASUS ROG Strix G15 (2021) Ryzen 7 Octa Core AM...     4.5
# 10  RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB ...     4.1
# 11  ASUS Vivobook Ultra 14 (2022) Core i5 11th Gen...     4.4
# 12  ASUS VivoBook 14 (2021) Celeron Dual Core - (4...     4.1
# 13  HP Intel Core i5 11th Gen - (8 GB/512 GB SSD/W...     4.2
# 14  Lenovo Celeron Dual Core - (4 GB/256 GB HDD/25...     3.8
# 15  HP 14s Intel Core i5 12th Gen - (16 GB/512 GB ...     4.2
# 16  ASUS Core i7 11th Gen - (16 GB/512 GB SSD/Wind...       4
# 17  Lenovo Athlon Dual Core 3150U - (4 GB/1 TB HDD...     3.8
# 18  ASUS Vivobook 15 Touch Core i3 11th Gen - (8 G...     4.3
# 19  HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/...     4.1
# 20  HP 15s Intel Core i5 12th Gen - (8 GB/512 GB S...     4.2
# 21  ASUS Vivobook 15 Core i3 10th Gen - (8 GB/512 ...     4.1
# 22  DELL Ryzen 3 Quad Core 5425U - (8 GB/256 GB SS...     4.4
# 23  ASUS ROG Strix G15 Ryzen 7 Octa Core AMD R7-48...     4.5
#
#                        num_ratings                           processor  \
# 0    9,965 Ratings & 1,000 Reviews  Intel Core i3 Processor (10th Gen)
# 1   11,810 Ratings & 1,198 Reviews     AMD Ryzen 5 Hexa Core Processor
# 2         366 Ratings & 35 Reviews   Intel Celeron Dual Core Processor
# 3      1,539 Ratings & 136 Reviews  Intel Core i3 Processor (11th Gen)
# 4         247 Ratings & 53 Reviews     AMD Ryzen 3 Dual Core Processor
# 5           14 Ratings & 1 Reviews  Intel Core i3 Processor (11th Gen)
# 6           10 Ratings & 1 Reviews  Intel Core i3 Processor (11th Gen)
# 7           32 Ratings & 1 Reviews  Intel Core i3 Processor (11th Gen)
# 8      1,340 Ratings & 166 Reviews     AMD Ryzen 5 Hexa Core Processor
# 9      2,015 Ratings & 256 Reviews     AMD Ryzen 7 Octa Core Processor
# 10     3,620 Ratings & 429 Reviews  Intel Core i5 Processor (11th Gen)
# 11        153 Ratings & 17 Reviews  Intel Core i5 Processor (11th Gen)
# 12        698 Ratings & 86 Reviews   Intel Celeron Dual Core Processor
# 13          25 Ratings & 5 Reviews  Intel Core i5 Processor (11th Gen)
# 14        204 Ratings & 17 Reviews   Intel Celeron Dual Core Processor
# 15     1,278 Ratings & 117 Reviews  Intel Core i5 Processor (12th Gen)
# 16         83 Ratings & 11 Reviews  Intel Core i7 Processor (11th Gen)
# 17          13 Ratings & 2 Reviews      AMD Athlon Dual Core Processor
# 18        314 Ratings & 42 Reviews  Intel Core i3 Processor (11th Gen)
# 19     1,060 Ratings & 106 Reviews     AMD Ryzen 3 Dual Core Processor
# 20     1,906 Ratings & 160 Reviews  Intel Core i5 Processor (12th Gen)
# 21        168 Ratings & 14 Reviews  Intel Core i3 Processor (10th Gen)
# 22         87 Ratings & 15 Reviews     AMD Ryzen 3 Quad Core Processor
# 23        193 Ratings & 18 Reviews     AMD Ryzen 7 Octa Core Processor
#
#                 ram                                  os  \
# 0     8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 1     8 GB DDR4 RAM  64 bit Windows 10 Operating System
# 2     8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 3     8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 4     8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 5     8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 6     8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 7     8 GB DDR4 RAM         Windows 11 Operating System
# 8     8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 9     8 GB DDR4 RAM  64 bit Windows 10 Operating System
# 10    8 GB DDR4 RAM         Windows 11 Operating System
# 11   16 GB DDR4 RAM  64 bit Windows 11 Operating System
# 12    4 GB DDR4 RAM  64 bit Windows 11 Operating System
# 13    8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 14  4 GB LPDDR4 RAM                DOS Operating System
# 15   16 GB DDR4 RAM  64 bit Windows 11 Operating System
# 16   16 GB DDR4 RAM         Windows 11 Operating System
# 17    4 GB DDR4 RAM                DOS Operating System
# 18    8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 19    8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 20    8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 21    8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 22    8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 23    8 GB DDR4 RAM  64 bit Windows 10 Operating System
#
#                   storage    price org_price
# 0              512 GB SSD  ₹32,990   ₹45,990
# 1              512 GB SSD  ₹49,990   ₹63,539
# 2              256 GB SSD  ₹28,490   ₹40,490
# 3              256 GB SSD  ₹35,990   ₹47,206
# 4              256 GB SSD  ₹26,990   ₹42,999
# 5              512 GB SSD  ₹33,599   ₹59,760
# 6     1 TB HDD|256 GB SSD  ₹35,499   ₹60,120
# 7     1 TB HDD|256 GB SSD  ₹39,990   ₹58,489
# 8              512 GB SSD  ₹52,990   ₹71,990
# 9              512 GB SSD  ₹75,490   ₹90,990
# 10             512 GB SSD  ₹39,990   ₹59,999
# 11             512 GB SSD  ₹53,990   ₹81,990
# 12             256 GB SSD  ₹23,990   ₹33,990
# 13             512 GB SSD  ₹52,990   ₹56,903
# 14  256 GB HDD|256 GB SSD  ₹19,990   ₹36,000
# 15             512 GB SSD  ₹58,899   ₹75,191
# 16             512 GB SSD  ₹56,990   ₹80,990
# 17               1 TB HDD  ₹18,990   ₹29,999
# 18             512 GB SSD  ₹41,990   ₹60,990
# 19             256 GB SSD  ₹29,990   ₹43,631
# 20             512 GB SSD  ₹56,899   ₹70,235
# 21             512 GB SSD  ₹33,990   ₹50,990
# 22             256 GB SSD  ₹35,990   ₹50,837
# 23             512 GB SSD  ₹76,990   ₹90,990

# %%
# extract the data for page number 1 only
page_number = 58
data = []

for i in range(1, page_number):

    # extract the page as a whole
    page = requests.get("https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=popularity&page={}".format(i))

    # parse the whole page using a html parser
    soup = BeautifulSoup(page.content, 'html.parser')
    # soup

    # find_all() searches for the all the tags where the class is found and 
    # returns a list of all the occurences 
    all_laps = soup.findAll('a', href=True, attrs={'class':"_1fQZEK"})

    # find the length of the elements extracted
    len(all_laps)
    
    for a in all_laps:
        
        processor = None
        ram = None
        os = None
        storage = None

        name = a.find('div', attrs={'class':'_4rR01T'})
        ratings = a.find('div', attrs={'class':'_3LWZlK'})
        num_ratings = a.find('span', attrs={'class':'_2_R_DZ'})

        price = a.find(class_='_30jeq3 _1_WHN1')
        org_price = a.find(class_='_3I9_wc _27UcVY')


        allspecs = a.find('ul', attrs={'class':'_1xgFaf'})
        sp = allspecs.findAll(class_="rgWa7D")

        for i in range(len(sp)):
            if('Processor' in sp[i].text  and 'Processor:' not in sp[i].text):
                processor = sp[i].text

            elif('RAM' in sp[i].text and 'RAM &' not in sp[i].text):
                ram = sp[i].text

            elif('Operating' in sp[i].text):
                os = sp[i].text

            elif('SSD' in sp[i].text or 'HDD' in sp[i].text):
                storage = sp[i].text

        data.append({'name': name.text,
                     'ratings': ratings.text if ratings is not None else '',
                     'num_ratings': num_ratings.text if num_ratings is not None else '',
                    'processor': processor,
                    'ram': ram,
                    'os': os,
                    'storage': storage if storage is not None else '',
                    'price': price.text,
                    'org_price': org_price.text if org_price is not None else ''})

# %%
data
# Out:
# [{'name': 'ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS | X515JA-E...',
#   'ratings': '4.3',
#   'num_ratings': '9,965 Ratings\xa0&\xa01,000 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹32,990',
#   'org_price': '₹45,990'},
#  {'name': 'HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 10/4 GB Graphics/NVIDIA GeForce ...',
#   'ratings': '4.4',
#   'num_ratings': '11,810 Ratings\xa0&\xa01,198 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹49,990',
#   'org_price': '₹63,539'},
#  {'name': 'Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop',
#   'ratings': '4.1',
#   'num_ratings': '366 Ratings\xa0&\xa035 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹28,490',
#   'org_price': '₹40,490'},
#  {'name': 'HP 14s Intel Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14s - dy2507TU Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '1,539 Ratings\xa0&\xa0136 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹35,990',
#   'org_price': '₹47,206'},
#  {'name': 'acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/Windows 11 Home) A315-23 Laptop',
#   'ratings': '4.2',
#   'num_ratings': '247 Ratings\xa0&\xa053 Reviews',
#   'processor': 'AMD Ryzen 3 Dual Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹26,990',
#   'org_price': '₹42,999'},
#  {'name': 'Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) V15 ITL G2 Laptop',
#   'ratings': '4.1',
#   'num_ratings': '14 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹33,599',
#   'org_price': '₹59,760'},
#  {'name': 'Lenovo V15 G2 Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) V15 ITL G2 Laptop',
#   'ratings': '3.9',
#   'num_ratings': '10 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹35,499',
#   'org_price': '₹60,120'},
#  {'name': 'DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) Vostro 3510 Thin and Light L...',
#   'ratings': '4.1',
#   'num_ratings': '32 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹39,990',
#   'org_price': '₹58,489'},
#  {'name': 'ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5 Hexa Core AMD R5-4600H - (8 GB/512 GB SSD/Windows 11 Ho...',
#   'ratings': '4.4',
#   'num_ratings': '1,340 Ratings\xa0&\xa0166 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹52,990',
#   'org_price': '₹71,990'},
#  {'name': 'ASUS ROG Strix G15 (2021) Ryzen 7 Octa Core AMD R7-4800H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graph...',
#   'ratings': '4.5',
#   'num_ratings': '2,015 Ratings\xa0&\xa0256 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹75,490',
#   'org_price': '₹90,990'},
#  {'name': 'RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop',
#   'ratings': '4.1',
#   'num_ratings': '3,620 Ratings\xa0&\xa0429 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹39,990',
#   'org_price': '₹59,999'},
#  {'name': 'ASUS Vivobook Ultra 14 (2022) Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) K413EA-EB522WS Thi...',
#   'ratings': '4.4',
#   'num_ratings': '153 Ratings\xa0&\xa017 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹53,990',
#   'org_price': '₹81,990'},
#  {'name': 'ASUS VivoBook 14 (2021) Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) X415MA-BV011W Thin and L...',
#   'ratings': '4.1',
#   'num_ratings': '698 Ratings\xa0&\xa086 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '4 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹23,990',
#   'org_price': '₹33,990'},
#  {'name': 'HP Intel Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s- fr4000TU Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '25 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹52,990',
#   'org_price': '₹56,903'},
#  {'name': 'Lenovo Celeron Dual Core - (4 GB/256 GB HDD/256 GB SSD/DOS) 82C3A00DIH Laptop',
#   'ratings': '3.8',
#   'num_ratings': '204 Ratings\xa0&\xa017 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '4 GB LPDDR4 RAM',
#   'os': 'DOS Operating System',
#   'storage': '256 GB HDD|256 GB SSD',
#   'price': '₹19,990',
#   'org_price': '₹36,000'},
#  {'name': 'HP 14s Intel Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14s - dy5005TU Thin and Light Lapto...',
#   'ratings': '4.2',
#   'num_ratings': '1,278 Ratings\xa0&\xa0117 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹58,899',
#   'org_price': '₹75,191'},
#  {'name': 'ASUS Core i7 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) X515EA-EJ701WS Thin and Light Laptop',
#   'ratings': '4',
#   'num_ratings': '83 Ratings\xa0&\xa011 Reviews',
#   'processor': 'Intel Core i7 Processor (11th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹56,990',
#   'org_price': '₹80,990'},
#  {'name': 'Lenovo Athlon Dual Core 3150U - (4 GB/1 TB HDD/DOS) E41-55 Thin and Light Laptop',
#   'ratings': '3.8',
#   'num_ratings': '13 Ratings\xa0&\xa02 Reviews',
#   'processor': 'AMD Athlon Dual Core Processor',
#   'ram': '4 GB DDR4 RAM',
#   'os': 'DOS Operating System',
#   'storage': '1 TB HDD',
#   'price': '₹18,990',
#   'org_price': '₹29,999'},
#  {'name': 'ASUS Vivobook 15 Touch Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EZ311WS Thin and Li...',
#   'ratings': '4.3',
#   'num_ratings': '314 Ratings\xa0&\xa042 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹41,990',
#   'org_price': '₹60,990'},
#  {'name': 'HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/Windows 11 Home) 15s-ey1508AU Thin and Light Laptop',
#   'ratings': '4.1',
#   'num_ratings': '1,060 Ratings\xa0&\xa0106 Reviews',
#   'processor': 'AMD Ryzen 3 Dual Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹29,990',
#   'org_price': '₹43,631'},
#  {'name': 'HP 15s Intel Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq5111TU Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '1,906 Ratings\xa0&\xa0160 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹56,899',
#   'org_price': '₹70,235'},
#  {'name': 'ASUS Vivobook 15 Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ382WS X515JA Laptop',
#   'ratings': '4.1',
#   'num_ratings': '168 Ratings\xa0&\xa014 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹33,990',
#   'org_price': '₹50,990'},
#  {'name': 'DELL Ryzen 3 Quad Core 5425U - (8 GB/256 GB SSD/Windows 11 Home) Vostro 3425 Thin and Light Laptop',
#   'ratings': '4.4',
#   'num_ratings': '87 Ratings\xa0&\xa015 Reviews',
#   'processor': 'AMD Ryzen 3 Quad Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹35,990',
#   'org_price': '₹50,837'},
#  {'name': 'ASUS ROG Strix G15 Ryzen 7 Octa Core AMD R7-4800H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVI...',
#   'ratings': '4.5',
#   'num_ratings': '193 Ratings\xa0&\xa018 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹76,990',
#   'org_price': '₹90,990'},
#  {'name': 'Lenovo Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 15IGL05 Thin and Light Laptop',
#   'ratings': '4',
#   'num_ratings': '100 Ratings\xa0&\xa011 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹28,490',
#   'org_price': '₹40,490'},
#  {'name': 'HP Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 11 Home) 14s-fy1003AU Thin and Light Laptop',
#   'ratings': '4.3',
#   'num_ratings': '208 Ratings\xa0&\xa018 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹50,499',
#   'org_price': '₹63,289'},
#  {'name': 'ASUS Vivobook 15 Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ382WS X515JA Laptop',
#   'ratings': '4.1',
#   'num_ratings': '168 Ratings\xa0&\xa014 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹33,990',
#   'org_price': '₹50,990'},
#  {'name': 'HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15s- eq2144au Thin and Light Laptop',
#   'ratings': '4.3',
#   'num_ratings': '1,056 Ratings\xa0&\xa082 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹45,827',
#   'org_price': '₹59,778'},
#  {'name': 'HP Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 11 Home) 15s- eq2182AU Thin and Light Laptop',
#   'ratings': '4.3',
#   'num_ratings': '278 Ratings\xa0&\xa033 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹49,123',
#   'org_price': '₹59,108'},
#  {'name': 'Infinix INBook X1 Neo Series Celeron Quad Core - (4 GB/128 GB SSD/Windows 11 Home) XL22 Thin and Light...',
#   'ratings': '4.1',
#   'num_ratings': '732 Ratings\xa0&\xa0119 Reviews',
#   'processor': 'Intel Celeron Quad Core Processor',
#   'ram': '4 GB LPDDR4X RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '128 GB SSD',
#   'price': '₹20,990',
#   'org_price': '₹29,990'},
#  {'name': 'DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) D560841WIN9S Thin and Ligh...',
#   'ratings': '4.2',
#   'num_ratings': '341 Ratings\xa0&\xa031 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹41,990',
#   'org_price': '₹61,202'},
#  {'name': 'HP 15s Intel Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fr2511TU Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '328 Ratings\xa0&\xa035 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹40,990',
#   'org_price': '₹50,585'},
#  {'name': 'RedmiBook Pro Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '4,306 Ratings\xa0&\xa0506 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹31,990',
#   'org_price': '₹51,999'},
#  {'name': 'MSI Katana GF66 Core i7 11th Gen - (16 GB/512 GB SSD/Windows 10 Home/6 GB Graphics/NVIDIA GeForce RTX ...',
#   'ratings': '4.3',
#   'num_ratings': '112 Ratings\xa0&\xa016 Reviews',
#   'processor': 'Intel Core i7 Processor (11th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹84,990',
#   'org_price': '₹1,23,990'},
#  {'name': 'HP Victus Intel Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GTX 1...',
#   'ratings': '4.3',
#   'num_ratings': '441 Ratings\xa0&\xa035 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹63,990',
#   'org_price': '₹83,039'},
#  {'name': 'ASUS VivoBook K15 OLED (2022) Ryzen 5 Hexa Core AMD R5-5500U - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Ho...',
#   'ratings': '4.4',
#   'num_ratings': '1,120 Ratings\xa0&\xa0131 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹52,990',
#   'org_price': '₹78,990'},
#  {'name': 'ASUS Vivobook Pro 15 Ryzen 7 Octa Core AMD R7-4800H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/...',
#   'ratings': '4.5',
#   'num_ratings': '741 Ratings\xa0&\xa091 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹59,990',
#   'org_price': '₹82,990'},
#  {'name': 'HP 14s Intel Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 14s - dy2508TU Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '3,440 Ratings\xa0&\xa0312 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹41,990',
#   'org_price': '₹49,509'},
#  {'name': 'DELL Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) New Inspiron 15 Metal Laptop Thin and Light...',
#   'ratings': '4.8',
#   'num_ratings': '11 Ratings\xa0&\xa00 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹67,490',
#   'org_price': '₹95,332'},
#  {'name': 'ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-BQ522WS Thin and Light La...',
#   'ratings': '4.3',
#   'num_ratings': '119 Ratings\xa0&\xa012 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹50,990',
#   'org_price': '₹69,990'},
#  {'name': 'APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGN63HN/A',
#   'ratings': '4.7',
#   'num_ratings': '8,724 Ratings\xa0&\xa0783 Reviews',
#   'processor': 'Apple M1 Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Mac OS Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹86,990',
#   'org_price': '₹99,900'},
#  {'name': 'SAMSUNG Galaxy Book Go Snapdragon 7c Gen 2 - (4 GB/128 GB EMMC Storage/Windows 11 Home) NP340XLA-KA1IN...',
#   'ratings': '4.3',
#   'num_ratings': '102 Ratings\xa0&\xa018 Reviews',
#   'processor': 'Qualcomm Snapdragon 7c Gen 2 Processor',
#   'ram': '4 GB LPDDR4X RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '',
#   'price': '₹32,990',
#   'org_price': '₹47,990'},
#  {'name': 'ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322WS Thin and Light La...',
#   'ratings': '4.3',
#   'num_ratings': '164 Ratings\xa0&\xa023 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹39,990',
#   'org_price': '₹50,990'},
#  {'name': 'Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce...',
#   'ratings': '4.3',
#   'num_ratings': '2,535 Ratings\xa0&\xa0215 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹52,990',
#   'org_price': '₹76,890'},
#  {'name': 'DELL Vostro Pentium Gold - (8 GB/256 GB SSD/Windows 11 Home) Vostro 3510 Thin and Light Laptop',
#   'ratings': '4.7',
#   'num_ratings': '12 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Pentium Gold Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹32,590',
#   'org_price': '₹54,392'},
#  {'name': 'MSI Bravo 15 Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/AMD Radeo...',
#   'ratings': '4.4',
#   'num_ratings': '2,107 Ratings\xa0&\xa0282 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹49,990',
#   'org_price': '₹72,990'},
#  {'name': 'HP Pavilion Ryzen 5 Hexa Core 5625U - (8 GB/512 GB SSD/Windows 11 Home) 14-EC1003AU Thin and Light Lap...',
#   'ratings': '4.3',
#   'num_ratings': '81 Ratings\xa0&\xa014 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹53,990',
#   'org_price': '₹63,325'},
#  {'name': 'HP Victus Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GTX ...',
#   'ratings': '5',
#   'num_ratings': '5 Ratings\xa0&\xa01 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹59,990',
#   'org_price': '₹76,021'},
#  {'name': 'acer Extensa Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) EX 215-54-583M Thin and Light Laptop',
#   'ratings': '3.9',
#   'num_ratings': '146 Ratings\xa0&\xa07 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹40,990',
#   'org_price': '₹57,999'},
#  {'name': 'Infinix INBook X2 Plus Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) XL25 Thin and Light Laptop',
#   'ratings': '4',
#   'num_ratings': '66 Ratings\xa0&\xa010 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB LPDDR4X RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹30,990',
#   'org_price': '₹44,990'},
#  {'name': 'ASUS TUF Gaming F15 (2022) Core i7 12th Gen - (16 GB/1 TB SSD/Windows 11 Home/6 GB Graphics/NVIDIA GeF...',
#   'ratings': '4.8',
#   'num_ratings': '25 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Intel Core i7 Processor (12th Gen)',
#   'ram': '16 GB DDR5 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB SSD',
#   'price': '₹1,18,990',
#   'org_price': '₹1,81,990'},
#  {'name': 'acer Aspire Core i3 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) A315-59 Notebook',
#   'ratings': '4.3',
#   'num_ratings': '34 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Intel Core i3 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹39,990',
#   'org_price': '₹54,999'},
#  {'name': 'HP 15s Intel Core i3 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq5007TU Thin and Light Laptop',
#   'ratings': '4.1',
#   'num_ratings': '35 Ratings\xa0&\xa08 Reviews',
#   'processor': 'Intel Core i3 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹47,490',
#   'org_price': '₹56,260'},
#  {'name': 'Lenovo Intel Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 81X800J3IN | 81X800LGIN Thin and Lig...',
#   'ratings': '4.3',
#   'num_ratings': '411 Ratings\xa0&\xa035 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹39,990',
#   'org_price': '₹59,890'},
#  {'name': 'ASUS TUF Gaming F17 (2022) with 90Whr Battery Core i7 12th Gen - (16 GB/1 TB SSD/Windows 11 Home/6 GB ...',
#   'ratings': '4.3',
#   'num_ratings': '37 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Intel Core i7 Processor (12th Gen)',
#   'ram': '16 GB DDR5 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB SSD',
#   'price': '₹1,09,990',
#   'org_price': '₹1,65,990'},
#  {'name': 'ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ522WS Thin and Light La...',
#   'ratings': '4.2',
#   'num_ratings': '149 Ratings\xa0&\xa015 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹50,990',
#   'org_price': '₹69,990'},
#  {'name': 'ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...',
#   'ratings': '4.4',
#   'num_ratings': '4,478 Ratings\xa0&\xa0432 Reviews',
#   'processor': 'Intel Core i5 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹58,990',
#   'org_price': '₹70,990'},
#  {'name': 'DELL Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) Inspiron 5320 Thin and Light Laptop',
#   'ratings': '5',
#   'num_ratings': '4 Ratings\xa0&\xa00 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR5 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹79,890',
#   'org_price': '₹99,498'},
#  {'name': 'Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) 15IML05 Thin and Light Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹33,990',
#   'org_price': '₹59,390'},
#  {'name': 'ASUS Vivobook 14 (2022) Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) X1402ZA-MW512WS Thin and...',
#   'ratings': '4.8',
#   'num_ratings': '14 Ratings\xa0&\xa03 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹66,990',
#   'org_price': '₹82,990'},
#  {'name': 'HP Athlon Dual Core 3050U - (8 GB/256 GB SSD/Windows 11 Home) 14s-fq0568AU Thin and Light Laptop',
#   'ratings': '4',
#   'num_ratings': '669 Ratings\xa0&\xa069 Reviews',
#   'processor': 'AMD Athlon Dual Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹27,990',
#   'org_price': '₹36,359'},
#  {'name': 'ASUS Core i3 12th Gen - (8 GB/256 GB SSD/Windows 11 Home) X1402ZA-EK391WS Laptop',
#   'ratings': '3.9',
#   'num_ratings': '18 Ratings\xa0&\xa06 Reviews',
#   'processor': 'Intel Core i3 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹44,990',
#   'org_price': '₹54,990'},
#  {'name': 'ASUS VivoBook Flip 14 Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) TP470EA-EC301WS 2 in 1 Lapt...',
#   'ratings': '4.4',
#   'num_ratings': '124 Ratings\xa0&\xa010 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB LPDDR4X RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹44,990',
#   'org_price': '₹63,990'},
#  {'name': 'DELL Inspiron Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) INSPIRON 5410 2 in 1 Laptop',
#   'ratings': '4.3',
#   'num_ratings': '375 Ratings\xa0&\xa035 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹54,300',
#   'org_price': '₹68,658'},
#  {'name': 'HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeF...',
#   'ratings': '4.4',
#   'num_ratings': '288 Ratings\xa0&\xa042 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹61,990',
#   'org_price': '₹81,869'},
#  {'name': 'ASUS TUF Gaming A17 with 90Whr Battery Ryzen 7 Octa Core AMD R7-4800H - (8 GB/512 GB SSD/Windows 11 Ho...',
#   'ratings': '4.4',
#   'num_ratings': '980 Ratings\xa0&\xa0126 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹81,990',
#   'org_price': '₹94,990'},
#  {'name': 'Lenovo IdeaPad Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GTX 16...',
#   'ratings': '4.3',
#   'num_ratings': '2,535 Ratings\xa0&\xa0215 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹54,990',
#   'org_price': '₹83,890'},
#  {'name': 'ASUS Vivobook 16X Ryzen 5 Hexa Core R5-5600H - (16 GB/512 GB SSD/Windows 11 Home) M1603QA-MB511WS Lapt...',
#   'ratings': '4.9',
#   'num_ratings': '7 Ratings\xa0&\xa00 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹54,990',
#   'org_price': '₹74,990'},
#  {'name': 'DELL Ryzen 5 Hexa Core AMD R5-5600H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce R...',
#   'ratings': '4.5',
#   'num_ratings': '244 Ratings\xa0&\xa023 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹77,490',
#   'org_price': '₹1,02,522'},
#  {'name': 'HP Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/Windows 11 Home) 15s-eq2143au Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '1,824 Ratings\xa0&\xa0198 Reviews',
#   'processor': 'AMD Ryzen 3 Quad Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹38,490',
#   'org_price': '₹45,991'},
#  {'name': 'HP Pavilion Intel Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14-dv2014TU Thin and Light Lap...',
#   'ratings': '4.4',
#   'num_ratings': '261 Ratings\xa0&\xa018 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹69,858',
#   'org_price': '₹80,596'},
#  {'name': 'HP Victus Ryzen 7 Octa Core 5800H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/AMD Radeon RX 5500M...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹66,990',
#   'org_price': '₹90,056'},
#  {'name': 'Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphic...',
#   'ratings': '4.4',
#   'num_ratings': '424 Ratings\xa0&\xa058 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹58,490',
#   'org_price': '₹76,890'},
#  {'name': 'HP Pavilion Intel Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) EG2035TU/ 15-EG2035TU Thin and...',
#   'ratings': '4.1',
#   'num_ratings': '76 Ratings\xa0&\xa09 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹74,990',
#   'org_price': '₹83,710'},
#  {'name': 'DELL Core i5 12th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) New Inspiron 15 Laptop Thin and Lig...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹57,990',
#   'org_price': '₹80,473'},
#  {'name': 'MSI Alpha 15 AMD Advantage Edition Ryzen 7 Octa Core 5800H - (8 GB/512 GB SSD/Windows 11 Home/8 GB Gra...',
#   'ratings': '4.5',
#   'num_ratings': '394 Ratings\xa0&\xa057 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹74,990',
#   'org_price': '₹1,11,990'},
#  {'name': 'ASUS TUF Gaming A15 with 90Whr Battery Ryzen 7 Octa Core 5800H - (16 GB/512 GB SSD/Windows 11 Home/6 G...',
#   'ratings': '4.5',
#   'num_ratings': '158 Ratings\xa0&\xa023 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹89,990',
#   'org_price': '₹1,07,990'},
#  {'name': 'APPLE 2022 MacBook AIR M2 - (16 GB/512 GB SSD/Mac OS Monterey) Z160000ZC',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Apple M2 Processor',
#   'ram': '16 GB Unified Memory RAM',
#   'os': 'Mac OS Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹1,50,990',
#   'org_price': '₹1,59,000'},
#  {'name': 'APPLE 2022 MacBook Pro M2 - (8 GB/512 GB SSD/Mac OS Monterey) MNEJ3HN/A',
#   'ratings': '4.6',
#   'num_ratings': '20 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Apple M2 Processor',
#   'ram': '8 GB Unified Memory RAM',
#   'os': 'Mac OS Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹1,39,990',
#   'org_price': '₹1,49,900'},
#  {'name': 'HP Pavilion Gaming Ryzen 7 Octa Core AMD R7-5800H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NV...',
#   'ratings': '4.3',
#   'num_ratings': '328 Ratings\xa0&\xa032 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹74,008',
#   'org_price': '₹92,404'},
#  {'name': 'ASUS ROG Strix G15 Ryzen 7 Octa Core AMD R7-4800H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVI...',
#   'ratings': '4.5',
#   'num_ratings': '1,204 Ratings\xa0&\xa0157 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹87,990',
#   'org_price': '₹1,07,990'},
#  {'name': 'HP Pavilion Ryzen 5 Hexa Core 5625U - (16 GB/512 GB SSD/Windows 11 Home) 14-EC1005AU Thin and Light La...',
#   'ratings': '5',
#   'num_ratings': '3 Ratings\xa0&\xa01 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹61,990',
#   'org_price': '₹69,082'},
#  {'name': 'APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGN93HN/A',
#   'ratings': '4.7',
#   'num_ratings': '8,724 Ratings\xa0&\xa0783 Reviews',
#   'processor': 'Apple M1 Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Mac OS Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹86,990',
#   'org_price': '₹99,900'},
#  {'name': 'ASUS Vivobook S14 OLED (2022) Intel EVO Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) S3402ZA-...',
#   'ratings': '4.4',
#   'num_ratings': '1,186 Ratings\xa0&\xa0164 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹74,990',
#   'org_price': '₹92,990'},
#  {'name': 'ASUS VivoBook 15 (2021) Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-BQ521WS Thin and L...',
#   'ratings': '4.2',
#   'num_ratings': '535 Ratings\xa0&\xa055 Reviews',
#   'processor': 'Intel Core i5 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹45,990',
#   'org_price': '₹64,990'},
#  {'name': 'APPLE 2022 MacBook Pro M2 - (8 GB/256 GB SSD/Mac OS Monterey) MNEP3HN/A',
#   'ratings': '4.7',
#   'num_ratings': '19 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Apple M2 Processor',
#   'ram': '8 GB Unified Memory RAM',
#   'os': 'Mac OS Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹1,21,990',
#   'org_price': '₹1,29,990'},
#  {'name': 'acer Aspire 3 Dual Core 3020e - (4 GB/256 GB SSD/Windows 11 Home) A314-22 Laptop',
#   'ratings': '4.1',
#   'num_ratings': '656 Ratings\xa0&\xa060 Reviews',
#   'processor': 'AMD Dual Core Processor',
#   'ram': '4 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹22,990',
#   'org_price': '₹34,999'},
#  {'name': 'ASUS Vivobook 14 (2022) Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) X1402ZA-EK522WS Thin and ...',
#   'ratings': '4.2',
#   'num_ratings': '10 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹56,990',
#   'org_price': '₹70,990'},
#  {'name': 'ASUS ZenBook Duo 14 (2021) Touch Panel Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) UX482EAR-K...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB LPDDR4X RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹74,990',
#   'org_price': '₹1,22,990'},
#  {'name': 'HP Pavilion Intel Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) 14-dv2053TU Thin and Light Lapt...',
#   'ratings': '4.2',
#   'num_ratings': '124 Ratings\xa0&\xa011 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹63,990',
#   'org_price': '₹73,688'},
#  {'name': 'DELL Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) New Inspiron 15 Laptop Thin and Light Laptop',
#   'ratings': '3.5',
#   'num_ratings': '11 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹57,990',
#   'org_price': '₹75,649'},
#  {'name': 'DELL Inspiron Core i3 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) Inspiron 7420 Thin and Light Laptop',
#   'ratings': '3.8',
#   'num_ratings': '10 Ratings\xa0&\xa04 Reviews',
#   'processor': 'Intel Core i3 Processor (12th Gen)',
#   'ram': '8 GB DDR5 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹61,390',
#   'org_price': '₹78,145'},
#  {'name': 'ASUS VivoBook K15 OLED Ryzen 7 Octa Core AMD R7-5700U - (16 GB/512 GB SSD/Windows 11 Home) KM513UA-L71...',
#   'ratings': '4.3',
#   'num_ratings': '1,005 Ratings\xa0&\xa0124 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹63,990',
#   'org_price': '₹86,990'},
#  {'name': 'DELL Core i7 12th Gen - (16 GB/512 GB SSD/Windows 11 Home/2 GB Graphics) Inspiron 7420 Thin and Light ...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i7 Processor (12th Gen)',
#   'ram': '16 GB DDR5 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹99,990',
#   'org_price': '₹1,29,402'},
#  {'name': 'HP Pavilion Ryzen 5 Hexa Core 5625U - (16 GB/512 GB SSD/Windows 11 Home) 14-EC1019AU Thin and Light La...',
#   'ratings': '4.5',
#   'num_ratings': '197 Ratings\xa0&\xa015 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹63,990',
#   'org_price': '₹72,536'},
#  {'name': 'DELL Vostro Ryzen 7 Octa Core 5825U - (16 GB/512 GB SSD/Windows 11 Home) Vostro 5625 Thin and Light La...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹76,205',
#   'org_price': '₹99,693'},
#  {'name': 'ASUS Vivobook Pro 15 Ryzen 7 Octa Core AMD R7-4800H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/...',
#   'ratings': '4.5',
#   'num_ratings': '741 Ratings\xa0&\xa091 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹59,990',
#   'org_price': '₹82,990'},
#  {'name': 'APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLY33HN/A',
#   'ratings': '4.8',
#   'num_ratings': '108 Ratings\xa0&\xa013 Reviews',
#   'processor': 'Apple M2 Processor',
#   'ram': '8 GB Unified Memory RAM',
#   'os': 'Mac OS Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹1,11,990',
#   'org_price': '₹1,19,900'},
#  {'name': 'ASUS TUF Gaming A17 (2022) with 90Whr Battery Ryzen 7 Octa Core AMD R7-6800H - (16 GB/512 GB SSD/Windo...',
#   'ratings': '4.6',
#   'num_ratings': '11 Ratings\xa0&\xa01 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹88,990',
#   'org_price': '₹1,31,990'},
#  {'name': 'HP Intel Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14-dy0212TU 2 in 1 Laptop',
#   'ratings': '4.2',
#   'num_ratings': '173 Ratings\xa0&\xa012 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹53,990',
#   'org_price': '₹58,174'},
#  {'name': 'ASUS Touchscreen Core i3 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) X1502ZA-EZ311WS Laptop',
#   'ratings': '4.3',
#   'num_ratings': '7 Ratings\xa0&\xa00 Reviews',
#   'processor': 'Intel Core i3 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹45,910',
#   'org_price': '₹62,990'},
#  {'name': 'ASUS Vivobook 15 OLED (2022) Core i3 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) X1505ZA-L1311WS Thin...',
#   'ratings': '4.2',
#   'num_ratings': '13 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i3 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹50,990',
#   'org_price': '₹66,990'},
#  {'name': 'ASUS Vivobook 15 Touch Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EZ501WS Thin and Li...',
#   'ratings': '4.3',
#   'num_ratings': '135 Ratings\xa0&\xa014 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹51,990',
#   'org_price': '₹74,990'},
#  {'name': 'ASUS Vivobook Pro 15 OLED Ryzen 7 Octa Core AMD R7-4800H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Grap...',
#   'ratings': '4.5',
#   'num_ratings': '613 Ratings\xa0&\xa092 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹65,990',
#   'org_price': '₹88,990'},
#  {'name': 'APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLY13HN/A',
#   'ratings': '4.9',
#   'num_ratings': '42 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Apple M2 Processor',
#   'ram': '8 GB Unified Memory RAM',
#   'os': 'Mac OS Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹1,11,990',
#   'org_price': '₹1,19,990'},
#  {'name': 'APPLE 2022 MacBook Pro M2 - (16 GB/512 GB SSD/Mac OS Monterey) Z16R000QK',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Apple M2 Processor',
#   'ram': '16 GB Unified Memory RAM',
#   'os': 'Mac OS Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹1,59,990',
#   'org_price': '₹1,68,900'},
#  {'name': 'MSI Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce RTX 3050/144 Hz) ...',
#   'ratings': '4.4',
#   'num_ratings': '2,501 Ratings\xa0&\xa0314 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹56,990',
#   'org_price': '₹83,990'},
#  {'name': 'Infinix INBook X2 Plus Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) XL25 Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '143 Ratings\xa0&\xa033 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB LPDDR4X RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹33,990',
#   'org_price': '₹49,990'},
#  {'name': 'APPLE 2022 MacBook Pro M2 - (8 GB/256 GB SSD/Mac OS Monterey) MNEH3HN/A',
#   'ratings': '4.6',
#   'num_ratings': '38 Ratings\xa0&\xa03 Reviews',
#   'processor': 'Apple M2 Processor',
#   'ram': '8 GB Unified Memory RAM',
#   'os': 'Mac OS Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹1,21,990',
#   'org_price': '₹1,29,900'},
#  {'name': 'DELL Inspiron Ryzen 5 Hexa Core 5625U - (8 GB/512 GB SSD/Windows 11 Home) Inspiron 3525 Thin and Light...',
#   'ratings': '4.2',
#   'num_ratings': '18 Ratings\xa0&\xa04 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹49,390',
#   'org_price': '₹67,503'},
#  {'name': 'ASUS ROG Strix G15 (2022) with 90Whr Battery Ryzen 7 Octa Core AMD R7-6800H - (16 GB/1 TB SSD/Windows ...',
#   'ratings': '4.6',
#   'num_ratings': '23 Ratings\xa0&\xa04 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR5 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '1 TB SSD',
#   'price': '₹1,24,990',
#   'org_price': '₹1,76,990'},
#  {'name': 'MSI Katana GF66 Core i7 12th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX 3...',
#   'ratings': '4.2',
#   'num_ratings': '37 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Intel Core i7 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹76,990',
#   'org_price': '₹1,06,990'},
#  {'name': 'ASUS Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X415JA-EK324WS Notebook',
#   'ratings': '4.6',
#   'num_ratings': '11 Ratings\xa0&\xa00 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹33,990',
#   'org_price': '₹45,499'},
#  {'name': 'acer Aspire 7 Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce...',
#   'ratings': '4.4',
#   'num_ratings': '5,458 Ratings\xa0&\xa0669 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹55,990',
#   'org_price': '₹89,999'},
#  {'name': 'DELL Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) New Inspiron 14 2-in-1 2 in 1 Laptop',
#   'ratings': '4.3',
#   'num_ratings': '3 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹76,519',
#   'org_price': '₹98,252'},
#  {'name': 'DELL Inspiron Pentium Silver - (8 GB/256 GB SSD/Windows 11 Home) Inspiron 3521 Notebook',
#   'ratings': '4.1',
#   'num_ratings': '328 Ratings\xa0&\xa032 Reviews',
#   'processor': 'Intel Pentium Silver Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹32,000',
#   'org_price': '₹44,319'},
#  {'name': 'MSI Delta 15 AMD Advantage Edition Ryzen 9 Octa Core 5900HX 5th Gen - (16 GB/1 TB SSD/Windows 11 Home/...',
#   'ratings': '4.7',
#   'num_ratings': '38 Ratings\xa0&\xa08 Reviews',
#   'processor': 'AMD Ryzen 9 Octa Core Processor (5th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB SSD',
#   'price': '₹1,09,990',
#   'org_price': '₹1,88,990'},
#  {'name': 'ASUS Vivobook Pro 15 OLED Ryzen 7 Octa Core AMD R7-4800H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Grap...',
#   'ratings': '4.5',
#   'num_ratings': '613 Ratings\xa0&\xa092 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹65,990',
#   'org_price': '₹88,990'},
#  {'name': 'HP Envy 13 Intel Evo Core i7 12th Gen - (16 GB/1 TB SSD/Windows 11 Home) x360-bf0063TU Thin and Light ...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i7 Processor (12th Gen)',
#   'ram': '16 GB LPDDR4X RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '1 TB SSD',
#   'price': '₹1,14,990',
#   'org_price': '₹1,27,090'},
#  {'name': 'ASUS VivoBook K15 OLED (2022) Core i5 11th Gen - (16 GB/1 TB HDD/256 GB SSD/Windows 11 Home) K513EA-L5...',
#   'ratings': '4.3',
#   'num_ratings': '639 Ratings\xa0&\xa084 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹64,990',
#   'org_price': '₹85,990'},
#  {'name': 'ASUS VivoBook K15 OLED (2022) Core i5 11th Gen - (16 GB/1 TB HDD/256 GB SSD/Windows 11 Home) K513EA-L5...',
#   'ratings': '4.3',
#   'num_ratings': '639 Ratings\xa0&\xa084 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹64,990',
#   'org_price': '₹85,990'},
#  {'name': 'ASUS VivoBook 14 (2022) Core i3 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) X1402ZA-EB311WS Thin and ...',
#   'ratings': '4.1',
#   'num_ratings': '31 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Intel Core i3 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹47,990',
#   'org_price': '₹62,990'},
#  {'name': 'Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14ITL05 Thin and Light Laptop',
#   'ratings': '4.2',
#   'num_ratings': '803 Ratings\xa0&\xa066 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹36,490',
#   'org_price': '₹60,890'},
#  {'name': 'HP Envy x360 Intel Evo Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) 15-ew0043TU Thin and Ligh...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹90,490',
#   'org_price': '₹1,04,768'},
#  {'name': 'HP Pavilion Intel Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) 14-ek0074TU Thin and Light Lap...',
#   'ratings': '4.4',
#   'num_ratings': '27 Ratings\xa0&\xa03 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹77,070',
#   'org_price': '₹85,837'},
#  {'name': 'ASUS Vivobook 14 (2022) Core i5 12th Gen - (16 GB/512 GB SSD/Windows 11 Home) X1402ZA-MW511WS Thin and...',
#   'ratings': '5',
#   'num_ratings': '4 Ratings\xa0&\xa00 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹66,990',
#   'org_price': '₹82,990'},
#  {'name': 'HP OMEN Ryzen 7 Octa Core AMD R7-6800H - (16 GB/512 GB SSD/Windows 11 Home/8 GB Graphics/AMD Radeon RX...',
#   'ratings': '4.5',
# ...
#   'ratings': '4.3',
#   'num_ratings': '3 Ratings\xa0&\xa00 Reviews',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹76,990',
#   'org_price': '₹90,058'},
#  {'name': 'Infinix X1 Slim Series Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) XL21 Thin and Light Laptop',
#   'ratings': '4.3',
#   'num_ratings': '1,550 Ratings\xa0&\xa0250 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '8 GB LPDDR4X RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹33,490',
#   'org_price': '₹54,999'},
#  {'name': 'ASUS EeeBook 12 Celeron Dual Core 4th Gen - (4 GB/64 GB EMMC Storage/Windows 10 Home) E210MA-GJ012T Th...',
#   'ratings': '3.9',
#   'num_ratings': '197 Ratings\xa0&\xa020 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor (4th Gen)',
#   'ram': '4 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '',
#   'price': '₹20,990',
#   'org_price': '₹25,990'},
#  {'name': 'Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core 4600H - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NVIDIA ...',
#   'ratings': '4.3',
#   'num_ratings': '402 Ratings\xa0&\xa049 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '1 TB HDD',
#   'price': '₹56,990',
#   'org_price': '₹76,890'},
#  {'name': 'HP 14s Core i3 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) 14s- DR2015TU Thin and Light Laptop',
#   'ratings': '4.3',
#   'num_ratings': '442 Ratings\xa0&\xa053 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹45,450',
#   'org_price': '₹53,823'},
#  {'name': 'HP Pavilion Intel Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15-eg1000TU Thin and Light Lapt...',
#   'ratings': '4.1',
#   'num_ratings': '41 Ratings\xa0&\xa02 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹66,890',
#   'org_price': '₹86,500'},
#  {'name': 'HP Intel Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Pro) 13-aw0211TU 2 in 1 Laptop',
#   'ratings': '5',
#   'num_ratings': '2 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i5 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹1,27,000',
#   'org_price': '₹1,52,042'},
#  {'name': 'DELL Inspiron Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10) Inspiron 3511 Thin and Light Laptop',
#   'ratings': '3.8',
#   'num_ratings': '66 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹43,590',
#   'org_price': '₹55,534'},
#  {'name': 'Lenovo IdeaPad 5 Pro Core i5 11th Gen - (16 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) 14ITL6 Thin a...',
#   'ratings': '4.1',
#   'num_ratings': '22 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': 'Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹69,000',
#   'org_price': '₹1,13,290'},
#  {'name': 'HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 10 Home) 15s-EQ2040AU Thin and Light Laptop',
#   'ratings': '4.3',
#   'num_ratings': '569 Ratings\xa0&\xa053 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹51,490',
#   'org_price': '₹60,999'},
#  {'name': 'DELL Inspiron 15 7000 Series Core i7 8th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home/2 GB Graphics...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i7 Processor (8th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '1 TB HDD|128 GB SSD',
#   'price': '₹89,990',
#   'org_price': '₹1,00,990'},
#  {'name': 'DELL Vostro Ryzen 3 Quad Core 5425U - (8 GB/256 GB SSD/Windows 11 Home) Vostro 3425 Thin and Light Lap...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'AMD Ryzen 3 Quad Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹50,852',
#   'org_price': ''},
#  {'name': 'MSI GF63 Thin Core i7 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650...',
#   'ratings': '4.5',
#   'num_ratings': '1,666 Ratings\xa0&\xa0232 Reviews',
#   'processor': 'Intel Core i7 Processor (9th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹66,990',
#   'org_price': '₹1,04,990'},
#  {'name': 'Lenovo Intel Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) 14IGL05 Thin and Light Laptop',
#   'ratings': '3.9',
#   'num_ratings': '33 Ratings\xa0&\xa02 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '4 GB LPDDR4 RAM',
#   'os': '64 bit Chrome Operating System',
#   'storage': '',
#   'price': '₹28,490',
#   'org_price': '₹39,990'},
#  {'name': 'acer Aspire 3 Pentium Quad Core - (4 GB/500 GB HDD/Linux) A315-31 Laptop',
#   'ratings': '4.2',
#   'num_ratings': '1,492 Ratings\xa0&\xa0304 Reviews',
#   'processor': 'Intel Pentium Quad Core Processor',
#   'ram': '4 GB DDR3 RAM',
#   'os': 'Linux/Ubuntu Operating System',
#   'storage': '500 GB HDD',
#   'price': '₹22,999',
#   'org_price': ''},
#  {'name': 'HP 15s Core i3 10th Gen - (4 GB/1 TB HDD/Windows 10 Home/2 GB Graphics) 15s-du2060TX Thin and Light La...',
#   'ratings': '3.6',
#   'num_ratings': '132 Ratings\xa0&\xa027 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '4 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '1 TB HDD',
#   'price': '₹41,990',
#   'org_price': '₹44,908'},
#  {'name': 'acer P2 Series Core i5 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) TMP214-52 Thin and Light Laptop',
#   'ratings': '4.1',
#   'num_ratings': '295 Ratings\xa0&\xa055 Reviews',
#   'processor': 'Intel Core i5 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '1 TB HDD',
#   'price': '₹48,990',
#   'org_price': '₹59,500'},
#  {'name': 'ASUS ExpertBook P1 Core i3 10th Gen - (4 GB/1 TB HDD/Endless) P1440FA-FQ2348P1400FA Thin and Light Lap...',
#   'ratings': '3.8',
#   'num_ratings': '189 Ratings\xa0&\xa026 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '4 GB DDR4 RAM',
#   'os': 'DOS Operating System',
#   'storage': '1 TB HDD',
#   'price': '₹32,990',
#   'org_price': '₹39,990'},
#  {'name': 'Lenovo Ideapad S340 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) S340-14IIL Thin and Light Lap...',
#   'ratings': '4.2',
#   'num_ratings': '525 Ratings\xa0&\xa088 Reviews',
#   'processor': 'Intel Core i3 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹42,490',
#   'org_price': '₹58,490'},
#  {'name': 'Primebook 4G Enabled Android Based MediaTek Kompanio 500 - (4 GB/128 GB EMMC Storage/Android 11) 4G Th...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'MediaTek MediaTek Kompanio 500 Processor',
#   'ram': '4 GB LPDDR4 RAM',
#   'os': 'Android Operating System',
#   'storage': '',
#   'price': '₹27,990',
#   'org_price': ''},
#  {'name': 'MICROSOFT Surface Laptop 3 Ryzen 5 Quad Core 3580U - (8 GB/128 GB SSD/Windows 10 Home) 1873 Laptop',
#   'ratings': '3.8',
#   'num_ratings': '9 Ratings\xa0&\xa00 Reviews',
#   'processor': 'AMD Ryzen 5 Quad Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '128 GB SSD',
#   'price': '₹99,990',
#   'org_price': '₹1,24,999'},
#  {'name': 'Lenovo Core i7 10th Gen - (16 GB/512 GB SSD/Windows 10 Pro) ThinkPad X1 Carbon Thin and Light Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i7 Processor (10th Gen)',
#   'ram': '16 GB LPDDR3 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹2,14,760',
#   'org_price': ''},
#  {'name': 'ASUS Chromebook Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) CX1101CMA-GJ0007 Chromebook',
#   'ratings': '3.6',
#   'num_ratings': '385 Ratings\xa0&\xa050 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '4 GB LPDDR4 RAM',
#   'os': '64 bit Chrome Operating System',
#   'storage': '',
#   'price': '₹19,990',
#   'org_price': '₹22,990'},
#  {'name': 'ASUS ExpertBook B9 Core i7 10th Gen - (16 GB/1 TB SSD/Windows 10 Pro) ExpertBook B9 B9450FA Thin and L...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i7 Processor (10th Gen)',
#   'ram': '16 GB LPDDR3 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '1 TB SSD',
#   'price': '₹1,69,490',
#   'org_price': '₹2,02,990'},
#  {'name': 'HP 250 G8 Core i3 11th Gen - (8 GB/512 GB SSD/DOS) 250 G8 Notebook',
#   'ratings': '4',
#   'num_ratings': '51 Ratings\xa0&\xa07 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'DOS Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹37,600',
#   'org_price': '₹46,900'},
#  {'name': 'DELL Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) D560745WIN9B Laptop',
#   'ratings': '3.3',
#   'num_ratings': '3 Ratings\xa0&\xa01 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹56,490',
#   'org_price': '₹61,202'},
#  {'name': 'ASUS Pentium Quad Core 10th Gen - (4 GB/128 GB SSD/128 GB EMMC Storage/Windows 11 Home) T3300KA-LQ121W...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Pentium Quad Core Processor (10th Gen)',
#   'ram': '4 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '128 GB SSD',
#   'price': '₹39,500',
#   'org_price': '₹69,500'},
#  {'name': 'ASUS Vivobook Core i3 11th Gen - (4 GB/256 GB SSD/Windows 10 Home) X415EA-EK302TS Thin and Light Lapto...',
#   'ratings': '4.5',
#   'num_ratings': '79 Ratings\xa0&\xa010 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '4 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹34,990',
#   'org_price': '₹44,990'},
#  {'name': 'ASUS Vivobook 15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ552WS Thin and Light La...',
#   'ratings': '4.2',
#   'num_ratings': '110 Ratings\xa0&\xa05 Reviews',
#   'processor': 'Intel Core i5 Processor (10th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹50,000',
#   'org_price': '₹59,999'},
#  {'name': 'Ultimus S152 Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) NU15U2INC44VN Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '4 GB LPDDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹23,990',
#   'org_price': '₹29,999'},
#  {'name': 'ASUS Zenbook 14 (2021) Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) UX425EA-KI501TS Thin and L...',
#   'ratings': '4.6',
#   'num_ratings': '94 Ratings\xa0&\xa014 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB LPDDR4X RAM',
#   'os': 'Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹72,990',
#   'org_price': '₹90,990'},
#  {'name': 'DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) Inspiron 3511,Inspiron 300...',
#   'ratings': '4.3',
#   'num_ratings': '1,888 Ratings\xa0&\xa0200 Reviews',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹41,900',
#   'org_price': '₹59,839'},
#  {'name': 'DELL Core i5 11th Gen - (16 GB/512 GB SSD/Windows 10) Inspiron 5410 Thin and Light Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹67,989',
#   'org_price': '₹88,546'},
#  {'name': 'ASUS Pro P5 Core i7 8th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Pro) Pro P5 P5440FA Thin and Light ...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i7 Processor (8th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '1 TB HDD|256 GB SSD',
#   'price': '₹98,912',
#   'org_price': ''},
#  {'name': 'ASUS Zenbook 14 ScreenPad Touch Panel Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphic...',
#   'ratings': '4.3',
#   'num_ratings': '58 Ratings\xa0&\xa07 Reviews',
#   'processor': 'Intel Core i5 Processor (11th Gen)',
#   'ram': '8 GB LPDDR4X RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹72,990',
#   'org_price': '₹1,10,990'},
#  {'name': 'DELL Vostro Ryzen 5 Quad Core R5-3450U - (8 GB/256 GB SSD/Windows 11 Home) Vostro 3405 Thin and Light ...',
#   'ratings': '4.4',
#   'num_ratings': '69 Ratings\xa0&\xa07 Reviews',
#   'processor': 'AMD Ryzen 5 Quad Core Processor',
#   'ram': '8 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '256 GB SSD',
#   'price': '₹46,500',
#   'org_price': '₹58,285'},
#  {'name': 'DELL Inspiron Ryzen 7 Octa Core 5700U - (16 GB/512 GB SSD/Windows 10) Inspiron 7415 2 in 1 Laptop',
#   'ratings': '4.2',
#   'num_ratings': '34 Ratings\xa0&\xa05 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 10 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹89,890',
#   'org_price': '₹1,01,529'},
#  {'name': 'HP OMEN Ryzen 7 Octa Core AMD R7-5800H - (16 GB/1 TB SSD/Windows 11 Home/AMD Radeon RX 6600M) 16-C0140...',
#   'ratings': '3.8',
#   'num_ratings': '5 Ratings\xa0&\xa01 Reviews',
#   'processor': 'AMD Ryzen 7 Octa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB SSD',
#   'price': '₹1,18,490',
#   'org_price': '₹1,40,347'},
#  {'name': 'Avita SATUS ULTIMUS Celeron Dual Core - (4 GB/128 GB SSD/Windows 11 Home) NU14A1INC43PN-MB Laptop',
#   'ratings': '3.9',
#   'num_ratings': '646 Ratings\xa0&\xa089 Reviews',
#   'processor': 'Intel Celeron Dual Core Processor',
#   'ram': '4 GB LPDDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '128 GB SSD',
#   'price': '₹17,490',
#   'org_price': '₹29,990'},
#  {'name': 'DELL Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Inspiron 3511 Thin and Light Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i3 Processor (11th Gen)',
#   'ram': '8 GB DDR4 RAM',
#   'os': 'Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹61,202',
#   'org_price': ''},
#  {'name': 'acer Predator Helios 300 Core i9 12th Gen - (16 GB/1 TB SSD/Windows 11 Home/6 GB Graphics/NVIDIA GeFor...',
#   'ratings': '4.6',
#   'num_ratings': '105 Ratings\xa0&\xa016 Reviews',
#   'processor': 'Intel Core i9 Processor (12th Gen)',
#   'ram': '16 GB DDR5 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '1 TB SSD',
#   'price': '₹1,59,990',
#   'org_price': '₹1,89,990'},
#  {'name': 'LG Gram Core i5 12th Gen - (8 GB/512 GB SSD/Windows 11 Home) 14Z90Q Thin and Light Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': 'Intel Core i5 Processor (12th Gen)',
#   'ram': '8 GB DDR5 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹89,990',
#   'org_price': '₹1,27,000'},
#  {'name': 'HP Envy x360 Ryzen 5 Hexa Core 5600U - (16 GB/512 GB SSD/Windows 11 Home) 13 x360-ay1035au 2 in 1 Lapt...',
#   'ratings': '4.5',
#   'num_ratings': '13 Ratings\xa0&\xa00 Reviews',
#   'processor': 'AMD Ryzen 5 Hexa Core Processor',
#   'ram': '16 GB DDR4 RAM',
#   'os': '64 bit Windows 11 Operating System',
#   'storage': '512 GB SSD',
#   'price': '₹89,999',
#   'org_price': '₹98,999'}]

# %%
df = pd.DataFrame.from_dict(data) 
df
# Out:
#                                                   name ratings  \
# 0    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...     4.3
# 1    HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (...     4.4
# 2    Lenovo Intel Celeron Dual Core - (8 GB/256 GB ...     4.1
# 3    HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...     4.2
# 4    acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...     4.2
# ..                                                 ...     ...
# 931  Avita SATUS ULTIMUS Celeron Dual Core - (4 GB/...     3.9
# 932  DELL Core i3 11th Gen - (8 GB/512 GB SSD/Windo...
# 933  acer Predator Helios 300 Core i9 12th Gen - (1...     4.6
# 934  LG Gram Core i5 12th Gen - (8 GB/512 GB SSD/Wi...
# 935  HP Envy x360 Ryzen 5 Hexa Core 5600U - (16 GB/...     4.5
#
#                         num_ratings                           processor  \
# 0     9,965 Ratings & 1,000 Reviews  Intel Core i3 Processor (10th Gen)
# 1    11,810 Ratings & 1,198 Reviews     AMD Ryzen 5 Hexa Core Processor
# 2          366 Ratings & 35 Reviews   Intel Celeron Dual Core Processor
# 3       1,539 Ratings & 136 Reviews  Intel Core i3 Processor (11th Gen)
# 4          247 Ratings & 53 Reviews     AMD Ryzen 3 Dual Core Processor
# ..                              ...                                 ...
# 931        646 Ratings & 89 Reviews   Intel Celeron Dual Core Processor
# 932                                  Intel Core i3 Processor (11th Gen)
# 933        105 Ratings & 16 Reviews  Intel Core i9 Processor (12th Gen)
# 934                                  Intel Core i5 Processor (12th Gen)
# 935          13 Ratings & 0 Reviews     AMD Ryzen 5 Hexa Core Processor
#
#                  ram                                  os     storage  \
# 0      8 GB DDR4 RAM  64 bit Windows 11 Operating System  512 GB SSD
# 1      8 GB DDR4 RAM  64 bit Windows 10 Operating System  512 GB SSD
# 2      8 GB DDR4 RAM  64 bit Windows 11 Operating System  256 GB SSD
# 3      8 GB DDR4 RAM  64 bit Windows 11 Operating System  256 GB SSD
# 4      8 GB DDR4 RAM  64 bit Windows 11 Operating System  256 GB SSD
# ..               ...                                 ...         ...
# 931  4 GB LPDDR4 RAM  64 bit Windows 11 Operating System  128 GB SSD
# 932    8 GB DDR4 RAM         Windows 11 Operating System  512 GB SSD
# 933   16 GB DDR5 RAM  64 bit Windows 11 Operating System    1 TB SSD
# 934    8 GB DDR5 RAM  64 bit Windows 11 Operating System  512 GB SSD
# 935   16 GB DDR4 RAM  64 bit Windows 11 Operating System  512 GB SSD
#
#          price  org_price
# 0      ₹32,990    ₹45,990
# 1      ₹49,990    ₹63,539
# 2      ₹28,490    ₹40,490
# 3      ₹35,990    ₹47,206
# 4      ₹26,990    ₹42,999
# ..         ...        ...
# 931    ₹17,490    ₹29,990
# 932    ₹61,202
# 933  ₹1,59,990  ₹1,89,990
# 934    ₹89,990  ₹1,27,000
# 935    ₹89,999    ₹98,999
#
# [936 rows x 9 columns]

# %%
df.to_csv('flipkart_laptop.csv', index=False)
