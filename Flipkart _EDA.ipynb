# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read the CSV File

# %%
df = pd.read_csv('laptop_eda.csv')
df
# Out:
#                                                   name  ratings  num_ratings  \
# 0    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...      4.3       9965.0
# 1    HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (...      4.4      11810.0
# 2    Lenovo Intel Celeron Dual Core - (8 GB/256 GB ...      4.1        366.0
# 3    HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...      4.2       1539.0
# 4    acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...      4.2        247.0
# ..                                                 ...      ...          ...
# 931  Avita SATUS ULTIMUS Celeron Dual Core - (4 GB/...      3.9        646.0
# 932  DELL Core i3 11th Gen - (8 GB/512 GB SSD/Windo...      NaN          NaN
# 933  acer Predator Helios 300 Core i9 12th Gen - (1...      4.6        105.0
# 934  LG Gram Core i5 12th Gen - (8 GB/512 GB SSD/Wi...      NaN          NaN
# 935  HP Envy x360 Ryzen 5 Hexa Core 5600U - (16 GB/...      4.5         13.0
#
# ...

# %% [raw]
# Numerical vs. Numerical
#
#     1. Scatterplot
#     2. Line plot
#     3.Heatmap for correlation
#     4.Joint plot
#
#
# Categorical vs. Numerical
#
#     1.Bar chart
#     2.Violin plot
#     3.Categorical box plot
#     4.Swarm plot
#
#
# Two Categorical Variables
#
#     1.Bar chart
#     2.Grouped bar chart
#     3.Point plot

# %%
df.tail()
# Out:
#                                                   name  ratings  num_ratings  \
# 931  Avita SATUS ULTIMUS Celeron Dual Core - (4 GB/...      3.9        646.0
# 932  DELL Core i3 11th Gen - (8 GB/512 GB SSD/Windo...      NaN          NaN
# 933  acer Predator Helios 300 Core i9 12th Gen - (1...      4.6        105.0
# 934  LG Gram Core i5 12th Gen - (8 GB/512 GB SSD/Wi...      NaN          NaN
# 935  HP Envy x360 Ryzen 5 Hexa Core 5600U - (16 GB/...      4.5         13.0
#
#                               processor  ram  \
# 931   Intel Celeron Dual Core Processor    4
# 932  Intel Core i3 Processor (11th Gen)    8
# 933  Intel Core i9 Processor (12th Gen)   16
# 934  Intel Core i5 Processor (12th Gen)    8
# 935     AMD Ryzen 5 Hexa Core Processor   16
#
#                                      os     storage   price  org_price  Brand  \
# 931  64 bit Windows 11 Operating System  128 GB SSD   17490    29990.0  Avita
# ...

# %%
df.shape
# Out:
# (936, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936 entries, 0 to 935
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         936 non-null    object
#  1   ratings      660 non-null    float64
#  2   num_ratings  660 non-null    float64
#  3   processor    936 non-null    object
#  4   ram          936 non-null    int64
#  5   os           936 non-null    object
#  6   storage      918 non-null    object
#  7   price        936 non-null    int64
#  8   org_price    894 non-null    float64
#  9   Brand        936 non-null    object
#  10  num_reviews  660 non-null    float64
#  11  ram_type     936 non-null    object
#  12  Discount     894 non-null    float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 95.2+ KB

# %%
df.describe(include='all')
# Out:
#                                                      name     ratings  \
# count                                                 936  660.000000
# unique                                                762         NaN
# top     Infinix X1 Slim Series Core i7 10th Gen - (16 ...         NaN
# freq                                                    4         NaN
# mean                                                  NaN    4.283030
# std                                                   NaN    0.363614
# min                                                   NaN    1.600000
# 25%                                                   NaN    4.100000
# 50%                                                   NaN    4.300000
# 75%                                                   NaN    4.500000
# max                                                   NaN    5.000000
#
#          num_ratings                           processor         ram  \
# ...

# %%
df.isnull().sum().sum()
# Out:
# 930

# %%
df.corr()
# Out:
#               ratings  num_ratings       ram     price  org_price  \
# ratings      1.000000     0.052719  0.258096  0.307621   0.322796
# num_ratings  0.052719     1.000000 -0.166055 -0.138658  -0.154774
# ram          0.258096    -0.166055  1.000000  0.747007   0.716563
# price        0.307621    -0.138658  0.747007  1.000000   0.909096
# org_price    0.322796    -0.154774  0.716563  0.909096   1.000000
# num_reviews  0.038242     0.976312 -0.160867 -0.145223  -0.160604
# Discount    -0.093100    -0.028886 -0.106797 -0.302531  -0.039630
#
#              num_reviews  Discount
# ratings         0.038242 -0.093100
# num_ratings     0.976312 -0.028886
# ram            -0.160867 -0.106797
# price          -0.145223 -0.302531
# org_price      -0.160604 -0.039630
# num_reviews     1.000000 -0.012089
# Discount       -0.012089  1.000000

# %%
sns.boxplot(df.price)
# Out:
# C:\Users\VaishaliParashar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
sns.boxplot(df.ratings)
# Out:
# C:\Users\VaishaliParashar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ratings'>

# %%
sns.boxplot(df.Discount)
# Out:
# C:\Users\VaishaliParashar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Discount'>

# %%
df.Brand.value_counts().plot(kind = 'bar' , figsize = (15,8))
# Out:
# <AxesSubplot:>

# %%
corrmat = df.corr()

# %%
plt.figure(figsize = (15,8))
sns.heatmap(corrmat, cmap='BrBG', annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(df.price , df.ram)
# Out:
# C:\Users\VaishaliParashar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='ram'>

# %%
sns.scatterplot(df.price , df.Discount)
# Out:
# C:\Users\VaishaliParashar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='Discount'>

# %% [markdown]
# ### Sort the dataframe on the basis of price

# %%
df = df.sort_values('price' , ascending=False)
df.head(10)
# Out:
#                                                   name  ratings  num_ratings  \
# 500  ASUS ROG Strix Scar 17 SE (2022) with 90Whr Ba...      NaN          NaN
# 202  ASUS ROG Zephyrus Duo 16 (2022) Dual Screen La...      NaN          NaN
# 255  ASUS ROG Zephyrus Duo 16 (2022) Dual Screen La...      NaN          NaN
# 277  ASUS ROG Zephyrus Duo 16 (2022) Dual Screen La...      NaN          NaN
# 245  ASUS ROG Zephyrus Duo 16 (2022) Dual Screen La...      NaN          NaN
# 305  HP Core i9 12th Gen - (32 GB/2 TB SSD/Windows ...      NaN          NaN
# 276  HP Core i9 12th Gen - (32 GB/2 TB SSD/Windows ...      NaN          NaN
# 605  ASUS Zenbook 17 Fold OLED Intel EVO Core i7 12...      NaN          NaN
# 168  APPLE 2021 Macbook Pro M1 Max - (32 GB/1 TB SS...      4.3         13.0
# 779  APPLE 2021 Macbook Pro M1 Max - (32 GB/1 TB SS...      4.3         13.0
#
#                               processor  ram  \
# 500  Intel Core i9 Processor (12th Gen)   32
# ...

# %% [markdown]
# ### Take non null rows based on ratings and store the result in a new dataframe

# %%
df_temp = df[pd.notnull(df['ratings'])]
df_temp
# Out:
#                                                   name  ratings  num_ratings  \
# 168  APPLE 2021 Macbook Pro M1 Max - (32 GB/1 TB SS...      4.3         13.0
# 779  APPLE 2021 Macbook Pro M1 Max - (32 GB/1 TB SS...      4.3         13.0
# 308  ASUS ROG Strix SCAR 15 (2022) Core i9 12th Gen...      5.0          4.0
# 260  APPLE 2021 Macbook Pro M1 Pro - (16 GB/1 TB SS...      4.8        117.0
# 280  APPLE 2021 Macbook Pro M1 Pro - (16 GB/1 TB SS...      4.8        117.0
# ..                                                 ...      ...          ...
# 763  Avita PURA APU Dual Core A6 - (4 GB/128 GB SSD...      3.7       1597.0
# 789  Avita PURA APU Dual Core A6 - (4 GB/128 GB SSD...      3.7       1597.0
# 931  Avita SATUS ULTIMUS Celeron Dual Core - (4 GB/...      3.9        646.0
# 521  Avita SATUS S111 Celeron Dual Core - (4 GB/128...      3.9        646.0
# 171  ASUS Chromebook Flip Touch Celeron Dual Core -...      4.0       1735.0
#
# ...

# %% [markdown]
# ### Highest Discount

# %%
df['Discount'].max()
# Out:
# 74.42082254336869

# %%
df[df['Discount'] ==df['Discount'].max()]
# Out:
#                                                   name  ratings  num_ratings  \
# 668  DELL Inspiron Core i5 11th Gen - (8 GB/512 GB ...      4.2        166.0
#
#                               processor  ram  \
# 668  Intel Core i5 Processor (11th Gen)    8
#
#                                      os     storage  price  org_price Brand  \
# 668  64 bit Windows 11 Operating System  512 GB SSD  73490   287304.0  DELL
#
#      num_reviews ram_type   Discount
# 668         14.0     DDR4  74.420823

# %% [markdown]
# ### Highest number of ratings

# %%
df[df['num_ratings'] == df['num_ratings'].max()]
# Out:
#                                                   name  ratings  num_ratings  \
# 400  HP Pavilion Gaming Ryzen 5 Quad Core 3550H - (...      4.2      15472.0
# 341  HP Pavilion Gaming Ryzen 5 Quad Core 3550H - (...      4.2      15472.0
#
#                            processor  ram                                  os  \
# 400  AMD Ryzen 5 Quad Core Processor    8  64 bit Windows 10 Operating System
# 341  AMD Ryzen 5 Quad Core Processor    8  64 bit Windows 10 Operating System
#
#       storage  price  org_price Brand  num_reviews ram_type  Discount
# 400  1 TB HDD  54990    56144.0    HP       2053.0     DDR4  2.055429
# 341  1 TB HDD  54990    56144.0    HP       2053.0     DDR4  2.055429

# %%
df.ram_type.value_counts()
# Out:
# DDR4       671
# DDR5        94
# LPDDR4X     67
# Unified     36
# LPDDR5      29
# LPDDR4      15
# LPDDR3      12
# DDR3        12
# Name: ram_type, dtype: int64
